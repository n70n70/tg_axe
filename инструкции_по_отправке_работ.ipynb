# %% [markdown]
# <a href="https://colab.research.google.com/github/n70n70/tg_axe/blob/master/%D0%B8%D0%BD%D1%81%D1%82%D1%80%D1%83%D0%BA%D1%86%D0%B8%D0%B8_%D0%BF%D0%BE_%D0%BE%D1%82%D0%BF%D1%80%D0%B0%D0%B2%D0%BA%D0%B5_%D1%80%D0%B0%D0%B1%D0%BE%D1%82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Адрес для отправки ДЗ**
# 	mtomovbs@gmail.com
#
# ---
# Для удобства проверки Ваших работ убедительно просим дальнейшие работы высылать по образцу:
#
# >  1 - в ТЕМЕ письма указывать:
# Python-{номер недели}-{номер практики}-{Номер подгруппы}-{ФамилияИмя}
# Например, Иванов Федор из 1 подгруппы сдает из 2 недели практику 1.3.
# ТОГДА ТЕМА будет Python-2-1.3-1-ИвановФедор
# P.S. Если у Вас одна практика на неделе она всегда будет обозначаться цифрой 1.
#
#
# > Alex F, [12.11.2021 23:17]
# PythonLaba1-1.1-3- ИвановИван - для ЛАБ
# Python-1-1.1-3- ИвановИван - для практики
# 1 - номер недели
# 1.1 - номер практики или лабы на этой неделе
# 3 номер подгруппы
#
# ---
#
# Alex F, [12.11.2021 20:22]
#
# Доброго времени суток, уважаемый участник курса! Мы рады Вам и первым выполненным работам.
#
# Информируем Вас о том, что в команде с Макаром Николаевичем работают его коллеги, эксперты курса - Евгений.
# Мы совместно будем проверять Ваши работы и давать обратную связь. С Евгением вы познакомитесь на онлайн встречах чуть позже.
#
# Для удобства проверки Ваших работ убедительно просим дальнейшие работы высылать по образцу:
#
# 1 - в ТЕМЕ письма указывать:
# Python-{номер недели}-{номер практики}-{Номер подгруппы}-{ФамилияИмя}
# Например, Иванов Федор из 1 подгруппы сдает из 2 недели практику 1.3.
# ТОГДА ТЕМА будет Python-2-1.3-1-ИвановФедор
#
# P.S. Если у Вас одна практика на неделе она всегда будет обозначаться цифрой 1.
#
# 2 - Хороший программист в начале своей карьеры подбирает для себя универсальный инструмент для написания кода.
#
# ---
#
# **Наши рекомендации:**
#
# Онлайн среда разработки Google Colab (https://colab.research.google.com/) - при таком выборе в самом письме прикладываем ссылку на выполненное задание в Google Colab (не забывайте предоставлять доступ по ссылке)
#
# Веб-приложение Jupiter Notebook (https://jupyter.org/) - при таком выборе в самом письме прикладываем файл с расширением *.ipynb
#
# Внимание! Название файла должно соответствовать номеру задания. Например, название файла для задачи 5 из практики 1.3 будет 1.3.5.ipynb.
#
# Если Вы по каким-то соображениям решили использовать другую среду разработки, то просим Вас высылать файл с программным кодом, Вашей работы, чтобы Эксперт смог ее запустить и протестировать. Что позволить более детализировано произвести проверку программного кода.
#
# 3 - Если Вы не сдаете практику, но у Вас возник уточняющий вопрос или решение письменной работы, то все это описываем в теле письма.
#
#
# Спасибо за понимание, мы рассчитываем на взаимное сотворчество в мире Python!
